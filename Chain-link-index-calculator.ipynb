# %%
#<--------------------------------SUBMARKET-LEVEL RENTAL CHAIN-LINKED INDEX CALCULATOR--------------------------------- ------>#

import numpy as np
import sys as system
from pandas import ExcelWriter

import pandas as pd
from pandas import Timestamp
import datetime

#function to get product_sum_of_rentals/sum_of_gfa_or_nla for previous and following quarters
def submarket_chain_link(df, category, quarter, year, years, Submarket):
    current_filter = df.loc[(df['Submarket' ]== Submarket) & (df['Category'] == category) & (df['Data Entry: Quarter'] == quarter) & (df['Data Entry: Year'] == year), ('Project ID', 'Rental', 'Sector', 'Category', 'GFA', 'NLA', 'RFP')]
    if quarter == 'Q1' and year == years[0]:
        following_filter = df.loc[(df['Submarket' ]== Submarket) & (df['Category'] == category) & (df['Data Entry: Quarter'] == 'Q2') & (df['Data Entry: Year'] == year), ('Project ID', 'Rental', 'Sector', 'Category', 'GFA', 'NLA', 'RFP')]
        numerator = 0
        denominator = 0
        sum_num = 0
        sum_denom = 0
        pq = 0
        fq = 0
        result = []
        for i in range(len(current_filter['Project ID'].tolist())):
           
                                 
                    
            
                                  
            for j in range(len(following_filter['Project ID'].tolist())):
                        if current_filter['Project ID'].tolist()[i] == following_filter['Project ID'].tolist()[j]:
                                 
                                 if current_filter['Sector'].tolist()[i] == 'Office' and current_filter['Rental'].tolist()[i] != 0 and following_filter['Rental'].tolist()[j] != 0:
                                    denom_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['GFA'].tolist()[i]                       
                                    denominator = denominator + denom_1
                                    sum_denom = sum_denom + current_filter['GFA'].tolist()[i]

                                
                                 elif current_filter['Sector'].tolist()[i] == 'Retail' and current_filter['Rental'].tolist()[i] != 0 and following_filter['Rental'].tolist()[j] != 0:
                                    denom_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['NLA'].tolist()[i]                       
                                    denominator = denominator + denom_1
                                    sum_denom = sum_denom + current_filter['NLA'].tolist()[i]
                                    
                                    
                                 
        
        if sum_num != 0:
                pq = numerator/sum_num
        else:
                pq = 0
        
        if sum_denom !=0:
                fq = denominator/sum_denom
        else:
                fq = 0
            
        result.append(pq)
        result.append(fq)
        
        return result
            
            
       

    elif quarter == 'Q1' and year != years[0]:
        previous_filter = df.loc[(df['Submarket' ]== Submarket) & (df['Category'] == category) & (df['Data Entry: Quarter'] == 'Q4') & (df['Data Entry: Year'] == year - 1), ('Project ID', 'Rental', 'Sector', 'Category', 'GFA', 'NLA', 'RFP')]
        following_filter = df.loc[(df['Submarket' ]== Submarket) & (df['Category'] == category) & (df['Data Entry: Quarter'] == 'Q2') & (df['Data Entry: Year'] == year), ('Project ID', 'Rental', 'Sector', 'Category', 'GFA', 'NLA', 'RFP')]
        numerator = 0
        denominator = 0
        sum_num = 0
        sum_denom = 0
        pq = 0
        fq = 0
        result = []
        for i in range(len(current_filter['Project ID'].tolist())):
            for k in range(len(previous_filter['Project ID'].tolist())):
#                 print(following_filter['Project ID'].tolist()[k])
                if current_filter['Project ID'].tolist()[i] ==  previous_filter['Project ID'].tolist()[k]:
                                 if current_filter['Sector'].tolist()[i] == 'Office' and current_filter['Rental'].tolist()[i] != 0 and previous_filter['Rental'].tolist()[k] != 0:
                                          num_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['GFA'].tolist()[i]
                                          numerator = numerator + num_1 
                                          sum_num = sum_num + current_filter['GFA'].tolist()[i]
                                
                                 elif current_filter['Sector'].tolist()[i] == 'Retail' and current_filter['Rental'].tolist()[i] != 0 and previous_filter['Rental'].tolist()[k] != 0:
                                    
                                    num_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['NLA'].tolist()[i]
                                    numerator = numerator + num_1 
                                    
                                    sum_num = sum_num + current_filter['NLA'].tolist()[i]
                                    
                                 
                    
            
                                  
            for j in range(len(following_filter['Project ID'].tolist())):
                        if current_filter['Project ID'].tolist()[i] == following_filter['Project ID'].tolist()[j]:
                                 
                                 if current_filter['Sector'].tolist()[i] == 'Office' and current_filter['Rental'].tolist()[i] != 0 and following_filter['Rental'].tolist()[j] != 0 :
                                    denom_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['GFA'].tolist()[i]                       
                                    denominator = denominator + denom_1
                                    sum_denom = sum_denom + current_filter['GFA'].tolist()[i]

                                
                                 elif current_filter['Sector'].tolist()[i] == 'Retail' and current_filter['Rental'].tolist()[i] != 0 and following_filter['Rental'].tolist()[j] != 0 :
                                    denom_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['NLA'].tolist()[i]                       
                                    denominator = denominator + denom_1
                                    sum_denom = sum_denom + current_filter['NLA'].tolist()[i]
                                    
                                    
                                 
        
        if sum_num != 0:
                pq = numerator/sum_num
        else:
                pq = 0
        
        if sum_denom !=0:
                fq = denominator/sum_denom
        else:
                fq = 0
            
        result.append(pq)
        result.append(fq)
            
            
        return result
               
                    
        
        
            
    elif quarter == 'Q2':
        
        
        previous_filter = df.loc[(df['Submarket' ]== Submarket) & (df['Category'] == category) & (df['Data Entry: Quarter'] == 'Q1') & (df['Data Entry: Year'] == year), ('Project ID', 'Rental', 'Sector', 'Category', 'GFA', 'NLA', 'RFP')]
        following_filter = df.loc[(df['Submarket' ]== Submarket) & (df['Category'] == category) & (df['Data Entry: Quarter'] == 'Q3') & (df['Data Entry: Year'] == year), ('Project ID', 'Rental', 'Sector', 'Category', 'GFA', 'NLA', 'RFP')]
        numerator = 0
        denominator = 0
        sum_num = 0
        sum_denom = 0
        pq = 0
        fq = 0
        result = []
#         
        for i in range(len(current_filter['Project ID'].tolist())):
            
            for k in range(len(previous_filter['Project ID'].tolist())):
                
                if current_filter['Project ID'].tolist()[i] ==  previous_filter['Project ID'].tolist()[k]:
                                 
                                 if current_filter['Sector'].tolist()[i] == 'Office' and current_filter['Rental'].tolist()[i] != 0 and previous_filter['Rental'].tolist()[k] != 0:
                                          num_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['GFA'].tolist()[i]
                                          numerator = numerator + num_1 
                                          sum_num = sum_num + current_filter['GFA'].tolist()[i]
                                
                                 elif current_filter['Sector'].tolist()[i] == 'Retail' and current_filter['Rental'].tolist()[i] != 0 and previous_filter['Rental'].tolist()[k] != 0:
                                    
                                    num_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['NLA'].tolist()[i]
                                    numerator = numerator + num_1 
                                    
                                    sum_num = sum_num + current_filter['NLA'].tolist()[i]
                                    
                                 
                
                    
            
                                  
            for j in range(len(following_filter['Project ID'].tolist())):
                        if current_filter['Project ID'].tolist()[i] == following_filter['Project ID'].tolist()[j]:
                                 
                                 if current_filter['Sector'].tolist()[i] == 'Office' and current_filter['Rental'].tolist()[i] != 0 and following_filter['Rental'].tolist()[j] != 0:
                                    
                                    denom_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['GFA'].tolist()[i]                       
                                    denominator = denominator + denom_1
                                    sum_denom = sum_denom + current_filter['GFA'].tolist()[i]

                                
                                 elif current_filter['Sector'].tolist()[i] == 'Retail' and current_filter['Rental'].tolist()[i] != 0 and following_filter['Rental'].tolist()[j] != 0 :
                                   
                                    denom_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['NLA'].tolist()[i]                       
                                    denominator = denominator + denom_1
                                    sum_denom = sum_denom + current_filter['NLA'].tolist()[i]
                                    
                                    
                                 
                    
                                 
                                    
        if sum_num != 0:
               
                pq = numerator/sum_num
        else:
               
                pq = 0                  
                            
        if sum_denom !=0:
                
                fq = denominator/sum_denom
        else:
                
                fq = 0
            
        result.append(pq)
        result.append(fq)
            
        return result
            
                            
        
        
    elif quarter == 'Q3' :
        previous_filter = df.loc[(df['Submarket' ]== Submarket) & (df['Category'] == category) & (df['Data Entry: Quarter'] == 'Q2') & (df['Data Entry: Year'] == year), ('Project ID', 'Rental', 'Sector', 'Category', 'GFA', 'NLA', 'RFP')]
        following_filter = df.loc[(df['Submarket' ]== Submarket) & (df['Category'] == category) & (df['Data Entry: Quarter'] == 'Q4') & (df['Data Entry: Year'] == year), ('Project ID', 'Rental', 'Sector', 'Category', 'GFA', 'NLA', 'RFP')]
        numerator = 0
        denominator = 0
        sum_num = 0
        sum_denom = 0
        pq = 0
        fq = 0
        result = []
        for i in range(len(current_filter['Project ID'].tolist())):
            for k in range(len(previous_filter['Project ID'].tolist())):
#                 print(following_filter['Project ID'].tolist()[k])
                if current_filter['Project ID'].tolist()[i] ==  previous_filter['Project ID'].tolist()[k]:
                                 if current_filter['Sector'].tolist()[i] == 'Office' and current_filter['Rental'].tolist()[i] != 0 and previous_filter['Rental'].tolist()[k] != 0:
                                          num_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['GFA'].tolist()[i]
                                          numerator = numerator + num_1 
                                          sum_num = sum_num + current_filter['GFA'].tolist()[i]
                                
                                 elif current_filter['Sector'].tolist()[i] == 'Retail' and current_filter['Rental'].tolist()[i] != 0 and previous_filter['Rental'].tolist()[k] != 0:
                                    
                                    num_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['NLA'].tolist()[i]
                                    numerator = numerator + num_1 
                                    
                                    sum_num = sum_num + current_filter['NLA'].tolist()[i]
                                    
                                 
                    
            
                                  
            for j in range(len(following_filter['Project ID'].tolist())):
                        if current_filter['Project ID'].tolist()[i] == following_filter['Project ID'].tolist()[j]:
                                 
                                 if current_filter['Sector'].tolist()[i] == 'Office' and current_filter['Rental'].tolist()[i] != 0 and following_filter['Rental'].tolist()[j] != 0:
                                    denom_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['GFA'].tolist()[i]                       
                                    denominator = denominator + denom_1
                                    sum_denom = sum_denom + current_filter['GFA'].tolist()[i]

                                
                                 elif current_filter['Sector'].tolist()[i] == 'Retail' and current_filter['Rental'].tolist()[i] != 0 and following_filter['Rental'].tolist()[j] != 0: 
                                    denom_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['NLA'].tolist()[i]                       
                                    denominator = denominator + denom_1
                                    sum_denom = sum_denom + current_filter['NLA'].tolist()[i]
                                    
                                    
                                 
        
        if sum_num != 0:
                pq = numerator/sum_num
        else:
                pq = 0
        
        if sum_denom !=0:
                fq = denominator/sum_denom
        else:
                fq = 0
            
        result.append(pq)
        result.append(fq)
            
            
        return result
        
    
    elif quarter == 'Q4' :
        previous_filter = df.loc[(df['Submarket' ]== Submarket) & (df['Category'] == category) & (df['Data Entry: Quarter'] == 'Q3') & (df['Data Entry: Year'] == year), ('Project ID', 'Rental', 'Sector', 'Category', 'GFA', 'NLA', 'RFP')]
        
        following_filter = df.loc[(df['Submarket' ]== Submarket) & (df['Category'] == category) & (df['Data Entry: Quarter'] == 'Q1') & (df['Data Entry: Year'] == year + 1), ('Project ID', 'Rental', 'Sector', 'Category', 'GFA', 'NLA', 'RFP')]
        numerator = 0
        denominator = 0
        sum_num = 0
        sum_denom = 0
        pq = 0
        fq = 0
        result = []
        for i in range(len(current_filter['Project ID'].tolist())):
            for k in range(len(previous_filter['Project ID'].tolist())):
#                 print(following_filter['Project ID'].tolist()[k])
                if current_filter['Project ID'].tolist()[i] ==  previous_filter['Project ID'].tolist()[k]:
#                                  print(current_filter['Project ID'].tolist()[i]) 
                                 if current_filter['Sector'].tolist()[i] == 'Office' and current_filter['Rental'].tolist()[i] != 0 and previous_filter['Rental'].tolist()[k] != 0:
                                          
                                          num_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['GFA'].tolist()[i]
                                          numerator = numerator + num_1 
                                          sum_num = sum_num + current_filter['GFA'].tolist()[i]
                                
                                 elif current_filter['Sector'].tolist()[i] == 'Retail' and current_filter['Rental'].tolist()[i] != 0 and previous_filter['Rental'].tolist()[k] != 0:
                                    
                                    num_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['NLA'].tolist()[i]
                                    numerator = numerator + num_1 
                                    
                                    sum_num = sum_num + current_filter['NLA'].tolist()[i]
                                    
                                 
            
                                  
            for j in range(len(following_filter['Project ID'].tolist())):
                        if current_filter['Project ID'].tolist()[i] == following_filter['Project ID'].tolist()[j]:
                                 
                                 if current_filter['Sector'].tolist()[i] == 'Office' and current_filter['Rental'].tolist()[i] != 0 and following_filter['Rental'].tolist()[j] != 0:
                                    
                                    denom_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['GFA'].tolist()[i]                       
                                    denominator = denominator + denom_1
                                    sum_denom = sum_denom + current_filter['GFA'].tolist()[i]

                                
                                 elif current_filter['Sector'].tolist()[i] == 'Retail' and current_filter['Rental'].tolist()[i] != 0 and following_filter['Rental'].tolist()[j] != 0: 
                                    
                                    denom_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['NLA'].tolist()[i]                       
                                    denominator = denominator + denom_1
                                    sum_denom = sum_denom + current_filter['NLA'].tolist()[i]
                                    
                                    
                                 
        
        
        if sum_num != 0:
                pq = numerator/sum_num
        else:
                pq = 0
        
        if sum_denom !=0:
                fq = denominator/sum_denom
        else:
                fq = 0
            
        result.append(pq)
        result.append(fq)
            
            
        return result
        
            
        
    else:
        result = []
        result.append(0)
        result.append(0)
        return result
    
        
    
#function to get product_sum_of_rentals/sum_of_gfa_or_nla for previous and following years
def submarket_chain_link_annual(df, category, quarter, entry_date, entry_dates, submarket):
    current_filter = df.loc[(df['Submarket' ]== submarket) & (df['Category'] == category) & (df['Data Entry: Quarter'] == 'TOTAL') & (df['Data Entry: Date'] == entry_date), ('Project ID', 'Rental', 'Sector', 'Category', 'GFA', 'NLA', 'RFP')]
    if entry_date == entry_dates[0] and quarter == 'TOTAL':
        following_filter = df.loc[(df['Submarket' ]== submarket) & (df['Category'] == category) & (df['Data Entry: Quarter'] == 'TOTAL') & (df['Data Entry: Date'] == Timestamp(str(int(entry_date.year + 1)) + '-' + str(entry_date.month) + '-' + '31')), ('Project ID', 'Rental', 'Sector', 'Category', 'GFA', 'NLA', 'RFP')]
        numerator = 0
        denominator = 0
        sum_num = 0
        sum_denom = 0
        pq = 0
        fq = 0
        result = []
        
        for i in range(len(current_filter['Project ID'].tolist())):
            
                
                    
            
                                  
            for j in range(len(following_filter['Project ID'].tolist())):
                        
                        if current_filter['Project ID'].tolist()[i] == following_filter['Project ID'].tolist()[j]:
                                 
                                 if current_filter['Sector'].tolist()[i] == 'Office' and current_filter['Rental'].tolist()[i] != 0 and following_filter['Rental'].tolist()[j] != 0 :
                                    denom_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['GFA'].tolist()[i]                       
                                    denominator = denominator + denom_1
                                    sum_denom = sum_denom + current_filter['GFA'].tolist()[i]

                                
                                 elif current_filter['Sector'].tolist()[i] == 'Retail' and current_filter['Rental'].tolist()[i] != 0 and following_filter['Rental'].tolist()[j] != 0 :
                                    denom_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['NLA'].tolist()[i]                       
                                    denominator = denominator + denom_1
                                    sum_denom = sum_denom + current_filter['NLA'].tolist()[i]
                                    
                                    
                                 
        
        if sum_num != 0:
                pq = numerator/sum_num
        else:
                pq = 0
        
        if sum_denom !=0:
                fq = denominator/sum_denom
        else:
                fq = 0
            
        result.append(pq)
        result.append(fq)
        
        
        return result
            
    elif entry_date <= pd.to_datetime('today') and quarter == 'TOTAL':
        
        
        
       
        previous_filter = df.loc[(df['Submarket' ]== submarket) & (df['Category'] == category) & (df['Data Entry: Quarter'] == 'TOTAL') & (df['Data Entry: Date'] == Timestamp(str(int(entry_date.year - 1)) + '-' + str(entry_date.month) + '-' + '31')), ('Project ID', 'Rental', 'Sector', 'Category', 'GFA', 'NLA', 'RFP')]
        following_filter = df.loc[(df['Submarket' ]== submarket) & (df['Category'] == category) & (df['Data Entry: Quarter'] == 'TOTAL') & (df['Data Entry: Date'] == Timestamp(str(int(entry_date.year + 1)) + '-' + str(entry_date.month) + '-' + '31')), ('Project ID', 'Rental', 'Sector', 'Category', 'GFA', 'NLA', 'RFP')]
        numerator = 0
        denominator = 0
        sum_num = 0
        sum_denom = 0
        pq = 0
        fq = 0
        result = []
        for i in range(len(current_filter['Project ID'].tolist())):
            
            for k in range(len(previous_filter['Project ID'].tolist())):
                
#                 print(following_filter['Project ID'].tolist()[k])
                if current_filter['Project ID'].tolist()[i] ==  previous_filter['Project ID'].tolist()[k]:
                                 
                                 if current_filter['Sector'].tolist()[i] == 'Office' and current_filter['Rental'].tolist()[i] != 0 and previous_filter['Rental'].tolist()[k] != 0:
                                          num_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['GFA'].tolist()[i]
                                          numerator = numerator + num_1 
                                          sum_num = sum_num + current_filter['GFA'].tolist()[i]
                                
                                 elif current_filter['Sector'].tolist()[i] == 'Retail' and current_filter['Rental'].tolist()[i] != 0 and previous_filter['Rental'].tolist()[k] != 0:
                                    
                                    num_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['NLA'].tolist()[i]
                                    numerator = numerator + num_1 
                                    
                                    sum_num = sum_num + current_filter['NLA'].tolist()[i]
                                    
                                 
                    
            
                                  
            for j in range(len(following_filter['Project ID'].tolist())):
                        if current_filter['Project ID'].tolist()[i] == following_filter['Project ID'].tolist()[j]:
                                
                                 if current_filter['Sector'].tolist()[i] == 'Office' and current_filter['Rental'].tolist()[i] != 0 and following_filter['Rental'].tolist()[j] != 0:
                                    denom_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['GFA'].tolist()[i]                       
                                    denominator = denominator + denom_1
                                    sum_denom = sum_denom + current_filter['GFA'].tolist()[i]

                                
                                 elif current_filter['Sector'].tolist()[i] == 'Retail' and current_filter['Rental'].tolist()[i] != 0 and following_filter['Rental'].tolist()[j] != 0 :
                                    denom_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['NLA'].tolist()[i]                       
                                    denominator = denominator + denom_1
                                    sum_denom = sum_denom + current_filter['NLA'].tolist()[i]
                                    
                                    
                                 
        
        if sum_num != 0:
                pq = numerator/sum_num
        else:
                pq = 0
        
        if sum_denom !=0:
                fq = denominator/sum_denom
        else:
                fq = 0
            
        result.append(pq)
        result.append(fq)
            
        
        return result
            
                            
        
        
    
    
    elif entry_date >= pd.to_datetime('today') and quarter == 'TOTAL':
        
        previous_filter = df.loc[(df['Submarket' ]== submarket) & (df['Category'] == category) &  (df['Data Entry: Quarter'] == 'TOTAL') &  (df['Data Entry: Date'] == Timestamp(str(int(entry_date.year - 1)) + '-' + str(entry_date.month) + '-' + '31')), ('Project ID', 'Rental', 'Sector', 'Category', 'GFA', 'NLA', 'RFP')]
        following_filter = current_filter
        numerator = 0
        denominator = 0
        sum_num = 0
        sum_denom = 0
        pq = 0
        fq = 0
        result = []
        for i in range(len(current_filter['Project ID'].tolist())):
            
            for k in range(len(previous_filter['Project ID'].tolist())):
#                 print(following_filter['Project ID'].tolist()[k])
                if current_filter['Project ID'].tolist()[i] ==  previous_filter['Project ID'].tolist()[k]:
                                 
                                 if current_filter['Sector'].tolist()[i] == 'Office' and current_filter['Rental'].tolist()[i] != 0 and previous_filter['Rental'].tolist()[k] != 0:
                                          num_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['GFA'].tolist()[i]
                                          numerator = numerator + num_1 
                                          sum_num = sum_num + current_filter['GFA'].tolist()[i]
                                
                                 elif current_filter['Sector'].tolist()[i] == 'Retail' and current_filter['Rental'].tolist()[i] != 0 and previous_filter['Rental'].tolist()[k] != 0:
                                    
                                    num_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['NLA'].tolist()[i]
                                    numerator = numerator + num_1 
                                    
                                    sum_num = sum_num + current_filter['NLA'].tolist()[i]
                                    
                                 
                    
            
            for j in range(len(following_filter['Project ID'].tolist())):
                        if current_filter['Project ID'].tolist()[i] == following_filter['Project ID'].tolist()[j]:
                                
                                 if current_filter['Sector'].tolist()[i] == 'Office' and current_filter['Rental'].tolist()[i] != 0 and following_filter['Rental'].tolist()[j] != 0:
                                    denom_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['GFA'].tolist()[i]                       
                                    denominator = denominator + denom_1
                                    sum_denom = sum_denom + current_filter['GFA'].tolist()[i]

                                
                                 elif current_filter['Sector'].tolist()[i] == 'Retail' and current_filter['Rental'].tolist()[i] != 0 and following_filter['Rental'].tolist()[j] != 0:
                                    denom_1 = current_filter['Rental'].tolist()[i] * 365 * ((12-current_filter['RFP'].tolist()[i])/12) * current_filter['NLA'].tolist()[i]                       
                                    denominator = denominator + denom_1
                                    sum_denom = sum_denom + current_filter['NLA'].tolist()[i]          
            
                                    
                                    
                                 
        
        if sum_num != 0:
                pq = numerator/sum_num
        else:
                pq = 0
        
        if sum_denom !=0:
                fq = denominator/sum_denom
        else:
                fq = 0
            
        result.append(pq)
        result.append(fq)
            
          
        return result
        
    else:
        return [0, 0]
        
    
    
    
#function to create first seven columns of output
def first_seven_quarterly_df(df, city_submarkets, quarters, years, category, entry_date, city_sectors, end_quarter):
    
    CLSMQH_quarters = []
    CLSMQH_years = []
    CLSMQH_Months = []
    CLSMQH_Submarkets = []
    CLSMQH_city = []
    CLSMQH_Date = []
    CLSMQH_Prev = []
    CLSMQH_Foll = [] 
    CLSMQH_Grade = []
    CLSMQH_Sectors = []
    
   
                    
    for i in range(len(city_sectors)):
        
        if len(city_sectors[list(city_sectors.keys())[i]]) != 1:
            print('error : a city has more than two sectors')
            system.exit()

    
    for i in range(len(city_submarkets)):
      
        for l in range(len(city_submarkets[list(city_submarkets.keys())[i]])):

            for z in range(len(category)):
                count = 0
                prev = 100
                for j in range(len(years)):
                    for k in range(len(quarters)):
                        
                        condition = quarters[k] != end_quarter or years[j] != years[len(years)-1]
                        if condition == False :
                            count = 1
                        if (quarters[k] != end_quarter or years[j] != years[len(years)-1]) and count != 1 : 
                            
                            
                            CLSMQH_Sectors.append(city_sectors[list(city_submarkets.keys())[i]][0])
                            CLSMQH_city.append(list(city_submarkets.keys())[i])
                            CLSMQH_Submarkets.append(city_submarkets[list(city_submarkets.keys())[i]][l])
                            CLSMQH_quarters.append(quarters[k])
                            CLSMQH_years.append(years[j])
                            
                            
                            if quarters[k] == 'Q1' and j == 0:
                                CLSMQH_Months.append(1)
                                CLSMQH_Date.append(Timestamp(str(int(years[j]))  + '-' + str(CLSMQH_Months[k]) + '-' + '1'))
                                
                    
                    
                            elif quarters[k] == 'Q1' and j != 0:
                                CLSMQH_Months.append(1)
                                CLSMQH_Date.append(Timestamp(str(int(years[j]))  + '-' + str(CLSMQH_Months[k]) + '-' + '1'))
                                
                                    
                               
                            elif quarters[k] == 'Q2':
                                CLSMQH_Months.append(4)
                                CLSMQH_Date.append(Timestamp(str(int(years[j])) + '-'  + str(CLSMQH_Months[k]) + '-' + '1'))
                               
                            elif quarters[k] == 'Q3':
                    
                                CLSMQH_Months.append(7)
                                CLSMQH_Date.append(Timestamp(str(int(years[j])) + '-'  + str(CLSMQH_Months[k]) + '-' + '1'))
                                
                            
                            elif quarters[k] == 'Q4':
                                CLSMQH_Months.append(10)
                                CLSMQH_Date.append(Timestamp(str(int(years[j])) + '-' + str(CLSMQH_Months[k]) + '-' + '1'))
                               
                    
                            CLSMQH_Grade.append(category[z])
                        
                            
                    
                        if j == len(years)-1 and k == len(quarters)-1:
                                for m in range(len(entry_date)):
                                    CLSMQH_quarters.append('TOTAL')
                                    CLSMQH_city.append(list(city_submarkets.keys())[i])
                                    CLSMQH_Submarkets.append(city_submarkets[list(city_submarkets.keys())[i]][l]) 
                                    CLSMQH_years.append(entry_date[m].year)
                                    CLSMQH_Grade.append(category[z])
                                    CLSMQH_Sectors.append(city_sectors[list(city_submarkets.keys())[i]][0])
                                    if j == 0:
                                       
                                        CLSMQH_Date.append(entry_date[m])
                                      
                    
                    
                                    elif entry_date[m] <= pd.to_datetime('today') :
                                       
                                        CLSMQH_Date.append(entry_date[m])
                                        
                    
                                    else:
                                        
                                        CLSMQH_Date.append(entry_date[m])
                       
                                        
                    
                                
                                
                            
                                
                    
                                    
            
            
            
        
        
        
    
                        
    list_of_tuples = list(zip(CLSMQH_city, CLSMQH_Grade, CLSMQH_Sectors, CLSMQH_Submarkets, CLSMQH_quarters, CLSMQH_years, CLSMQH_Date))
    list_of_tuples
    df_1 = pd.DataFrame(list_of_tuples, columns = ['City', 'Category', 'Sector', 'Submarket', 'Quarter', 'Year','Date'])
    
    return df_1
    
    
#function to save resulting .xlsx file
def save_xls(list_dfs, xls_path, sheet_names):
    with ExcelWriter(xls_path) as writer:
        for n, df in enumerate(list_dfs):
            df.to_excel(writer, sheet_names[n], index = False)
        writer.save()

#function to calculate rental_chain_linked_index for both quarterly and annual calculations
def ret_submarkets_CLG_quarterly(quarterly, city_submarkets, category, years, quarters, entry_dates, annual, end_quarter):

    chain_link_df = []
  
  
    
    for i in range(len(city_submarkets)):
        
        for l in range(len(city_submarkets[list(city_submarkets.keys())[i]])):
#             count = count + 1
#             print(count)
            for z in range(len(category)):
                count = 0
                prev = 100
                for j in range(len(years)):
                    for k in range(len(quarters)):
                        condition = quarters[k] != end_quarter or years[j] != years[len(years)-1]
                        if condition == False :
                            count = 1
                        if (quarters[k] != end_quarter or years[j] != years[len(years)-1]) and count != 1 : 
                            this_pq_fq = submarket_chain_link(quarterly, category[z], quarters[k], years[j], years, city_submarkets[list(city_submarkets.keys())[i]][l])
                    
                            if k !=0 :
                                last_pq_fq = submarket_chain_link(quarterly, category[z], quarters[k-1], years[j], years, city_submarkets[list(city_submarkets.keys())[i]][l])
                        
                                if last_pq_fq[1] != 0:
                                        q_to_q_change = (this_pq_fq[0] / last_pq_fq[1]) - 1 
                                        chain_link_index = prev * (1 + q_to_q_change)
                                        chain_link_df.append(chain_link_index)
                                        prev = chain_link_index
                                else:
                                        q_to_q_change = 0
                                        chain_link_index = prev * (1 + q_to_q_change)
                                        chain_link_df.append(chain_link_index)
                                        prev = chain_link_index
                            
                        
                        
                            elif k == 0 and j != 0:
                                last_pq_fq = submarket_chain_link(quarterly, category[z], quarters[len(quarters)-1], years[j-1], years, city_submarkets[list(city_submarkets.keys())[i]][l])
                                if last_pq_fq[1] != 0:
                                        q_to_q_change = (this_pq_fq[0] / last_pq_fq[1]) - 1 
                                        chain_link_index = prev * (1 + q_to_q_change)
                                        chain_link_df.append(chain_link_index)
                                        prev = chain_link_index
                                else:
                                        q_to_q_change = 0
                                        chain_link_index = prev * (1 + q_to_q_change)
                                        chain_link_df.append(chain_link_index)
                                        prev = chain_link_index
                        
                        
                            elif k == 0 and j == 0:
                                chain_link_index = 100
                                chain_link_df.append(chain_link_index)
                         
                                prev = chain_link_index
                        
                        if j == len(years)-1 and k == len(quarters)-1:
                            prev = 100
                            for m in range(len(entry_dates)):
                                this_pq_fq = submarket_chain_link_annual(annual, category[z], 'TOTAL', entry_dates[m], entry_dates, city_submarkets[list(city_submarkets.keys())[i]][l])
                    
                                if m !=0 :
                                        last_pq_fq = submarket_chain_link_annual(annual, category[z], 'TOTAL', entry_dates[m-1], entry_dates, city_submarkets[list(city_submarkets.keys())[i]][l])
                        
                                        if last_pq_fq[1] != 0:
                            
                                                   y_to_y_change = (this_pq_fq[0] / last_pq_fq[1]) - 1 
                                                   chain_link_index = prev * (1 + y_to_y_change)
                                                   chain_link_df.append(chain_link_index)
                                                   prev = chain_link_index
                                        else:
                                                   y_to_y_change = 0
                                                   chain_link_index = prev * (1 + y_to_y_change)
                                                   chain_link_df.append(chain_link_index)
                                                   prev = chain_link_index
                            
                        
                        
                    
                    
                        
                                else:
                                    chain_link_index = 100
                                    chain_link_df.append(chain_link_index)
                         
                                    prev = chain_link_index
                
                             
                    
                   
    return chain_link_df

#getting input data, splitting into retail and office data,  running data and assembling the output is done by calling the main() function.
def main():
    print('Provide the path of the input file :')
    path = input()
    try:
        file = pd.read_excel(path, low_memory = False)
    except:
        print('File provided was not a .xlsx file. Wait, while converting ....')
        file = pd.read_csv(path, low_memory = False)
        

    
    
    file = file.fillna(0)
    retail = file.loc[(file['Sector'] == 'Retail'), ('Project ID', 'Data Entry: Date', 'Data Entry: Quarter', 'Data Entry: Year', 'Rental', 'Sector', 'Category', 'GFA', 'NLA', 'Submarket','City', 'RFP')]
    office = file.loc[(file['Sector'] == 'Office'), ('Project ID', 'Data Entry: Date', 'Data Entry: Quarter', 'Data Entry: Year', 'Rental', 'Sector', 'Category', 'GFA', 'NLA', 'Submarket','City', 'RFP')]
    
    Retail_Quarterly = retail.loc[(retail['Data Entry: Quarter'] == 'Q1') | (retail['Data Entry: Quarter'] == 'Q2') | (retail['Data Entry: Quarter'] == 'Q3') | (retail['Data Entry: Quarter'] == 'Q4'), ('Project ID', 'Data Entry: Date', 'Data Entry: Quarter', 'Data Entry: Year', 'Rental', 'Sector', 'Category', 'GFA', 'NLA', 'Submarket','City', 'RFP')]
    Office_Quarterly = office.loc[(office['Data Entry: Quarter'] == 'Q1') | (office['Data Entry: Quarter'] == 'Q2') | (office['Data Entry: Quarter'] == 'Q3') | (office['Data Entry: Quarter'] == 'Q4'), ('Project ID', 'Data Entry: Date', 'Data Entry: Quarter', 'Data Entry: Year', 'Rental', 'Sector', 'Category', 'GFA', 'NLA', 'Submarket','City', 'RFP')]
    Retail_Annual = retail.loc[(retail['Data Entry: Quarter'] == 'TOTAL'), ('Project ID', 'Data Entry: Quarter', 'Data Entry: Year', 'Data Entry: Date', 'Rental', 'Sector', 'Category', 'GFA', 'NLA', 'Submarket', 'City', 'RFP')]
    Office_Annual = office.loc[(office['Data Entry: Quarter'] == 'TOTAL'), ('Project ID', 'Data Entry: Quarter', 'Data Entry: Year', 'Data Entry: Date', 'Rental', 'Sector', 'Category', 'GFA', 'NLA', 'Submarket', 'City', 'RFP')]
    
    Office_Annual['Data Entry: Date'] = pd.to_datetime(pd.Series(Office_Annual['Data Entry: Date']))
    Retail_Annual['Data Entry: Date'] = pd.to_datetime(pd.Series(Retail_Annual['Data Entry: Date']))
    retail_submarkets = retail.Submarket.unique()
    office_submarkets = office.Submarket.unique()
    retail_cities = retail.City.unique()
    office_cities = office.City.unique()
   
    
    city_submarkets_retail = {k:[] for k in retail_cities} 
    city_sectors_retail = {k:[] for k in retail_cities}
    for i in range(len(city_submarkets_retail)):
            retail_submarkets = retail.loc[(retail['City'] == list(city_submarkets_retail.keys())[i]) , ('Submarket')].unique()
            for j in range(len(retail_submarkets)):
                 if retail_submarkets[j] != 'Market':
                        city_submarkets_retail[list(city_submarkets_retail.keys())[i]].append(retail_submarkets[j])

            
    for i in range(len(city_sectors_retail)):
             retail_sectors = retail.loc[(retail['City'] == list(city_sectors_retail.keys())[i]) , ('Sector')].unique()
             for j in range(len(retail_sectors)):
        
                        city_sectors_retail[list(city_sectors_retail.keys())[i]].append(retail_sectors[j])

    
    city_submarkets_office = {k:[] for k in office_cities} 
    city_sectors_office = {k:[] for k in office_cities}
    for i in range(len(city_submarkets_office)):
            office_submarkets = office.loc[(office['City'] == list(city_submarkets_office.keys())[i]) , ('Submarket')].unique()
            for j in range(len(office_submarkets)):
                 if office_submarkets[j] != 'Market':
                        city_submarkets_office[list(city_submarkets_office.keys())[i]].append(office_submarkets[j])

            
    for i in range(len(city_sectors_office)):
             office_sectors = office.loc[(office['City'] == list(city_sectors_office.keys())[i]) , ('Sector')].unique()
             for j in range(len(office_sectors)):
        
                        city_sectors_office[list(city_sectors_office.keys())[i]].append(office_sectors[j])

                   
    quarters = ['Q1', 'Q2', 'Q3', 'Q4']
    category = ['Grade B', 'Overall', 'Grade A']
    while True:
        print('Enter starting year for quarterly calculations')
        start_year = input()
        print('Enter ending year for quarterly calculations')
        end_year = input()
        if int(start_year) in file['Data Entry: Year'].unique() and int(end_year) in file['Data Entry: Year'].unique():
            break
        else:
            print('Years entered do not exist in the file inputted. Please try again')
   
        
    
    print('Upto which quarter of', end_year, '. Enter the next quarter of the quarter up till which you want the quarterly chain-link index to be calculated. For instance if Q3 is the last quarter you want then enter Q4, if Q4 is the last quarter then leave as blank and press enter')
    end_quarter = input()
    years = range(int(start_year), int(end_year) + 1) 
    
    while True:
        print('Enter starting year for annual calculations')
        start_year_annual = input()
        print('Enter ending year for annual calculations')
        end_year_annual = input()
        if int(start_year_annual) in file['Data Entry: Year'].unique() and int(end_year_annual) in file['Data Entry: Year'].unique():
            break
        else:
            print('Years entered do not exist in the file inputted. Please try again')
    
    years_annual = range(int(start_year_annual), int(end_year_annual) + 1)
     
    print('Processing, please wait .............')
    
    
    entry_dates = []
    for i in range(len(years_annual)):
        entry_dates.append(Timestamp(str(int(years_annual[i])) + '-'  + str(12) + '-' + '31'))
    list_dfs = []
    
    
    sheet_names = ['Chain-Link']
    submarkets_CLG_quarterly_retail = {k:[] for k in retail_submarkets}
    submarkets_CLG_quarterly_office = {k:[] for k in office_submarkets}

    
    
    df_1_retail = first_seven_quarterly_df(retail, city_submarkets_retail, quarters, years, category, entry_dates, city_sectors_retail, end_quarter)
    

    
    submarkets_CLG_quarterly_retail = ret_submarkets_CLG_quarterly(Retail_Quarterly, city_submarkets_retail, category, years, quarters, entry_dates, Retail_Annual, end_quarter)
    df_2_retail = pd.DataFrame(submarkets_CLG_quarterly_retail, columns = ['Rental Chain-linked Index'])
    submarkets_quarterly_CLG_retail = pd.concat([df_1_retail, df_2_retail], axis=1)


    df_1_office = first_seven_quarterly_df(office, city_submarkets_office, quarters, years, category, entry_dates, city_sectors_office, end_quarter)
    

    
    submarkets_CLG_quarterly_office = ret_submarkets_CLG_quarterly(Office_Quarterly, city_submarkets_office, category, years, quarters, entry_dates, Office_Annual, end_quarter)
    df_2_office = pd.DataFrame(submarkets_CLG_quarterly_office, columns = ['Rental Chain-linked Index'])
    submarkets_quarterly_CLG_office = pd.concat([df_1_office, df_2_office], axis=1)
    
    submarkets_quarterly_CLG = pd.concat([submarkets_quarterly_CLG_retail, submarkets_quarterly_CLG_office])
    

    list_dfs.append(submarkets_quarterly_CLG)
    print('Done')
    print('Provide path to save file in .xlsx format :')
    path_save = input()
    save_xls(list_dfs, path_save , sheet_names )
    print('Saving .....')
    print('File saved at', path_save)
   


        
           
        
    
             
    
#executing main() function
main()
